# %% [markdown]
# # 🤖 Mini GPT Local
#
# No API key required. This notebook downloads the open-source model and runs it inside the Colab runtime.

# %%
# !git clone https://github.com/abhishekdata9868-web/mini-gpt-local.git
# %cd mini-gpt-local
# !pip install -q -r requirements.txt
# %run app.py
