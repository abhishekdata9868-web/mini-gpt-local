# %% [markdown]
# # 🧠 MiniGPT — From Scratch
#
# This notebook trains a small Transformer language model from randomly initialized weights. No OpenAI/OpenRouter/Gemini API key is used.
#
# ⚠️ This is a learning model, not ChatGPT-level intelligence. It learns text patterns from the training corpus.

# %%
# !pip install -q torch
# %cd /content/mini-gpt-local
# !python from_scratch/train.py
